# %%
import pandas as pd
import matplotlib

df = pd.read_csv('Final Dataset/masterlist_lyrics_with_features_cleaned_top300.csv')

for column in df.columns:
    print(f"{column}, {type(column)}")
# Out:
# Artist and Title, <class 'str'>
# Artist, <class 'str'>
# Year, <class 'str'>
# Streams, <class 'str'>
# Daily, <class 'str'>
# Title, <class 'str'>
# Lyrics, <class 'str'>
# language, <class 'str'>
# duration_ms, <class 'str'>
# id, <class 'str'>
# href, <class 'str'>
# isrc, <class 'str'>
# acousticness, <class 'str'>
# danceability, <class 'str'>
# energy, <class 'str'>
# instrumentalness, <class 'str'>
# key, <class 'str'>
# liveness, <class 'str'>
# loudness, <class 'str'>
# mode, <class 'str'>
# speechiness, <class 'str'>
# tempo, <class 'str'>
# valence, <class 'str'>
